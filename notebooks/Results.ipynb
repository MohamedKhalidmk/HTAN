# %% [markdown]
# # HTAN — Hyper TransAttUNet
# ### Medical Image Segmentation Experiments
# ---

# %% [markdown]
# ## 0. Setup

# %%
import os
import sys
import json
import random
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
import torch

PROJECT_ROOT = Path("..").resolve()
sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

print(f"Project root : {PROJECT_ROOT}")
print(f"PyTorch      : {torch.__version__}")
print(f"CUDA         : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU          : {torch.cuda.get_device_name(0)}")
# Out:
# Project root : /home/ubuntu/HTAN-2
# PyTorch      : 2.7.1+cu118
# CUDA         : True
# GPU          : NVIDIA A10G

# %% [markdown]
# ---
# # 1. ISIC-2018 — Skin Lesion Segmentation

# %% [markdown]
# ## 1.0 Download Data

# %%
from datasets.isic_dataset import download_isic
download_isic()
# Out:
# ISIC images already downloaded, skipping.
# ISIC masks already downloaded, skipping.
#
# ISIC-2018 ready.

# %% [markdown]
# ## 1.1 Verify Data

# %%
TRAIN_IMG_DIR  = Path("/opt/dlami/nvme/HTAN/data/isic/train_images")
TRAIN_MASK_DIR = Path("/opt/dlami/nvme/HTAN/data/isic/train_masks")

imgs  = sorted([f for f in TRAIN_IMG_DIR.iterdir() if f.suffix.lower() in {".jpg", ".jpeg", ".png"}])
masks = sorted([f for f in TRAIN_MASK_DIR.iterdir() if f.suffix.lower() == ".png"])

print(f"Images : {len(imgs)}")
print(f"Masks  : {len(masks)}")
print(f"Match  : {'YES' if len(imgs) == len(masks) else 'NO — CHECK THIS'}")
# Out:
# Images : 2594
# Masks  : 2594
# Match  : YES

# %%
# 3 random samples
samples = random.sample(imgs, 3)
fig, axes = plt.subplots(3, 2, figsize=(10, 12))
fig.suptitle("ISIC-2018 Sample Images", fontsize=14, fontweight="bold")

for i, img_path in enumerate(samples):
    mask_path = TRAIN_MASK_DIR / (img_path.stem + "_segmentation.png")
    axes[i, 0].imshow(Image.open(img_path).convert("RGB"))
    axes[i, 0].set_title(f"Input: {img_path.name}")
    axes[i, 0].axis("off")
    axes[i, 1].imshow(Image.open(mask_path).convert("L"), cmap="gray")
    axes[i, 1].set_title(f"Mask: {mask_path.name}")
    axes[i, 1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.2 Sanity Check — Model Forward Pass

# %%
from models.transattunet.TransAttUnet import TransAttUNet_R
from models.baselines.unet import UNet
from models.baselines.doubleunet import DoubleUNet
from models.htan.htan import HTAN_1, HTAN_2, HTAN_1_Hres_only

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
dummy  = torch.randn(2, 3, 256, 256).to(DEVICE)

models_to_check = {
    "unet":             UNet(),
    "doubleunet":       DoubleUNet(),
    "transattunet":     TransAttUNet_R(),
    "htan_1_n2":        HTAN_1(expansion_n=2),
    "htan_1_n4":        HTAN_1(expansion_n=4),
    "htan_2_n2":        HTAN_2(expansion_n=2),
    "htan_2_n4":        HTAN_2(expansion_n=4),
    "htan_1_hres_only": HTAN_1_Hres_only(expansion_n=4),
}

print(f"{'Model':<22} {'Params':>12} {'Output':>15} {'Status'}")
print("-" * 60)

for name, model in models_to_check.items():
    try:
        model = model.to(DEVICE).eval()
        with torch.no_grad():
            out = model(dummy)
        n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
        print(f"{name:<22} {n_params:>12,} {str(tuple(out.shape)):>15}   OK")
    except Exception as e:
        print(f"{name:<22} ERROR — {str(e)[:50]}")
    finally:
        del model
        torch.cuda.empty_cache()
# Out:
# Model                        Params          Output Status
# ------------------------------------------------------------
# unet                     17,267,393 (2, 1, 256, 256)   OK
# doubleunet                9,245,850 (2, 1, 256, 256)   OK
# transattunet             41,309,441 (2, 1, 256, 256)   OK
# htan_1_n2                49,701,132 (2, 1, 256, 256)   OK
# htan_1_n4                74,869,020 (2, 1, 256, 256)   OK
# htan_2_n2                60,912,535 (2, 1, 256, 256)   OK
# htan_2_n4               129,073,079 (2, 1, 256, 256)   OK
# htan_1_hres_only         66,480,402 (2, 1, 256, 256)   OK

# %% [markdown]
# ## 1.3 Training
#
# Each cell trains one model independently. Resume is automatic if interrupted.

# %%
# 1.3.1 U-Net
# !python3 train.py --model unet --dataset isic

# %%
# 1.3.2 DoubleU-Net
# !python3 train.py --model doubleunet --dataset isic

# %%
# !rm -f /opt/dlami/nvme/HTAN/saves/transattunet/resume_checkpoint.pth
# !rm -f /opt/dlami/nvme/HTAN/saves/transattunet/best_model.pth

# %%
# 1.3.3 TransAttUNet (official code)
# !python3 train.py --model transattunet --dataset isic
# Out:
# Seed set to 123
#
# Model:   transattunet
# Dataset: isic
# Device:  cuda
# Epochs:  100
# Optimizer: SGD
# Checkpoint: /opt/dlami/nvme/HTAN/saves/transattunet
#
# ISIC — Total: 2594 | Train: 2074 | Val: 520
# Trainable parameters: 41,309,441
#
# Resuming from: /opt/dlami/nvme/HTAN/saves/transattunet/resume_checkpoint.pth
# Resumed from epoch 80, best Dice: 0.8903
# Epoch  81/100 | LR: 1.00e-06 | Train: 0.1076 | Val: 0.1330 | Dice: 88.93% | IoU: 80.78%
# Epoch  82/100 | LR: 1.00e-06 | Train: 0.1047 | Val: 0.1338 | Dice: 88.86% | IoU: 80.68%
# Epoch  83/100 | LR: 1.00e-06 | Train: 0.1059 | Val: 0.1326 | Dice: 88.80% | IoU: 80.65%
# Epoch  84/100 | LR: 1.00e-06 | Train: 0.1023 | Val: 0.1343 | Dice: 88.63% | IoU: 80.37%
# Epoch  85/100 | LR: 1.00e-06 | Train: 0.1041 | Val: 0.1324 | Dice: 88.82% | IoU: 80.68%
# Epoch  86/100 | LR: 1.00e-06 | Train: 0.1158 | Val: 0.1362 | Dice: 88.54% | IoU: 80.24%
# Epoch  87/100 | LR: 1.00e-06 | Train: 0.1163 | Val: 0.1371 | Dice: 88.42% | IoU: 80.03%
# Epoch  88/100 | LR: 1.00e-06 | Train: 0.1170 | Val: 0.1355 | Dice: 88.57% | IoU: 80.34%
# Epoch  89/100 | LR: 1.00e-06 | Train: 0.1128 | Val: 0.1333 | Dice: 88.74% | IoU: 80.55%
# Epoch  90/100 | LR: 1.00e-06 | Train: 0.1146 | Val: 0.1344 | Dice: 88.73% | IoU: 80.49%
# Epoch  91/100 | LR: 1.00e-06 | Train: 0.1184 | Val: 0.1343 | Dice: 88.58% | IoU: 80.30%
# Epoch  92/100 | LR: 1.00e-06 | Train: 0.1201 | Val: 0.1366 | Dice: 88.55% | IoU: 80.20%
# Epoch  93/100 | LR: 1.00e-06 | Train: 0.1168 | Val: 0.1345 | Dice: 88.63% | IoU: 80.37%
# Epoch  94/100 | LR: 1.00e-06 | Train: 0.1150 | Val: 0.1431 | Dice: 87.98% | IoU: 79.40%
# Epoch  95/100 | LR: 1.00e-06 | Train: 0.1132 | Val: 0.1368 | Dice: 88.36% | IoU: 79.99%
# Epoch  96/100 | LR: 1.00e-06 | Train: 0.1149 | Val: 0.1376 | Dice: 88.45% | IoU: 80.11%
# Epoch  97/100 | LR: 1.00e-06 | Train: 0.1154 | Val: 0.1358 | Dice: 88.50% | IoU: 80.21%
# Epoch  98/100 | LR: 1.00e-06 | Train: 0.1152 | Val: 0.1335 | Dice: 88.71% | IoU: 80.51%
# Epoch  99/100 | LR: 1.00e-06 | Train: 0.1149 | Val: 0.1352 | Dice: 88.60% | IoU: 80.29%
# Epoch 100/100 | LR: 1.00e-06 | Train: 0.1157 | Val: 0.1351 | Dice: 88.62% | IoU: 80.31%
#
# Training complete. Best Validation Dice: 89.03%

# %%
# !python3 evaluate.py --model transattunet --dataset isic
# Out:
# Evaluating transattunet...
# ISIC — Total: 2594 | Train: 2074 | Val: 520
#
# =========================================================
# Model                    Dice    IoU    ACC    REC    PRE
# =========================================================
# transattunet            89.02  80.94  95.62  87.59  91.84
# =========================================================
#
# Results saved to /opt/dlami/nvme/HTAN/results/isic

# %%
# 1.3.4 HTAN_1 n=2
# !python3 train.py --model htan_1_n2 --dataset isic
# Out:
# Seed set to 123
#
# Model:   htan_1_n2
# Dataset: isic
# Device:  cuda
# Epochs:  100
# Optimizer: ADAMW
# Checkpoint: /opt/dlami/nvme/HTAN/saves/htan_1_n2
# ISIC — Total: 2594 | Train: 2074 | Val: 520
# Trainable parameters: 49,701,132
#
# Epoch   1/100 | LR: 1.00e-04 | Train: 0.3797 | Val: 0.3101 | Dice: 75.84% | IoU: 62.72%
#   New best Dice: 75.84% — saved.
# Epoch   2/100 | LR: 1.00e-04 | Train: 0.2771 | Val: 0.2278 | Dice: 82.14% | IoU: 71.08%
#   New best Dice: 82.14% — saved.
# Epoch   3/100 | LR: 9.99e-05 | Train: 0.2473 | Val: 0.1981 | Dice: 83.83% | IoU: 73.32%
#   New best Dice: 83.83% — saved.
# Epoch   4/100 | LR: 9.98e-05 | Train: 0.2247 | Val: 0.1929 | Dice: 84.37% | IoU: 74.18%
#   New best Dice: 84.37% — saved.
# Epoch   5/100 | LR: 9.96e-05 | Train: 0.2071 | Val: 0.1832 | Dice: 85.09% | IoU: 75.25%
#   New best Dice: 85.09% — saved.
# Epoch   6/100 | LR: 9.94e-05 | Train: 0.1949 | Val: 0.1889 | Dice: 84.05% | IoU: 73.79%
# Epoch   7/100 | LR: 9.91e-05 | Train: 0.1877 | Val: 0.1713 | Dice: 85.10% | IoU: 75.44%
#   New best Dice: 85.10% — saved.
# Epoch   8/100 | LR: 9.88e-05 | Train: 0.1807 | Val: 0.1587 | Dice: 87.27% | IoU: 78.29%
#   New best Dice: 87.27% — saved.
# Epoch   9/100 | LR: 9.84e-05 | Train: 0.1762 | Val: 0.1801 | Dice: 85.91% | IoU: 76.17%
# Epoch  10/100 | LR: 9.80e-05 | Train: 0.1652 | Val: 0.1586 | Dice: 87.06% | IoU: 77.86%
# Epoch  11/100 | LR: 9.76e-05 | Train: 0.1656 | Val: 0.1897 | Dice: 83.09% | IoU: 72.69%
# Epoch  12/100 | LR: 9.71e-05 | Train: 0.1637 | Val: 0.1595 | Dice: 87.07% | IoU: 78.03%
# Epoch  13/100 | LR: 9.65e-05 | Train: 0.1630 | Val: 0.1516 | Dice: 87.31% | IoU: 78.46%
#   New best Dice: 87.31% — saved.
# Epoch  14/100 | LR: 9.59e-05 | Train: 0.1597 | Val: 0.1603 | Dice: 86.88% | IoU: 77.81%
# Epoch  15/100 | LR: 9.53e-05 | Train: 0.1575 | Val: 0.1529 | Dice: 87.26% | IoU: 78.44%
# Epoch  16/100 | LR: 9.46e-05 | Train: 0.1503 | Val: 0.1479 | Dice: 87.12% | IoU: 78.22%
# Epoch  17/100 | LR: 9.39e-05 | Train: 0.1510 | Val: 0.1493 | Dice: 87.31% | IoU: 78.42%
#   New best Dice: 87.31% — saved.
# Epoch  18/100 | LR: 9.31e-05 | Train: 0.1460 | Val: 0.1364 | Dice: 88.65% | IoU: 80.41%
#   New best Dice: 88.65% — saved.
# Epoch  19/100 | LR: 9.23e-05 | Train: 0.1449 | Val: 0.1744 | Dice: 84.19% | IoU: 74.38%
# Epoch  20/100 | LR: 9.14e-05 | Train: 0.1393 | Val: 0.1537 | Dice: 86.59% | IoU: 77.51%
# Epoch  21/100 | LR: 9.05e-05 | Train: 0.1405 | Val: 0.1561 | Dice: 86.53% | IoU: 77.52%
# Epoch  22/100 | LR: 8.96e-05 | Train: 0.1444 | Val: 0.1674 | Dice: 85.85% | IoU: 76.32%
# Epoch  23/100 | LR: 8.86e-05 | Train: 0.1388 | Val: 0.1373 | Dice: 88.42% | IoU: 80.13%

# %%
# 1.3.5 HTAN_1 n=4
# !python3 train.py --model htan_1_n4 --dataset isic

# %%
# 1.3.6 HTAN_2 n=2
# !python3 train.py --model htan_2_n2 --dataset isic

# %%
# 1.3.7 HTAN_2 n=4
# !python3 train.py --model htan_2_n4 --dataset isic

# %%
# 1.3.8 HTAN_1 Hres-only (ablation)
# !python3 train.py --model htan_1_hres_only --dataset isic

# %% [markdown]
# ## 1.4 Evaluate All Models

# %%
# !python evaluate.py --model all --dataset isic

# %% [markdown]
# ## 1.5 Results Table

# %%
RESULTS_DIR = Path("/opt/dlami/nvme/HTAN/results/isic")
SAVES_ROOT  = Path("/opt/dlami/nvme/HTAN/saves")

# Paper numbers — taken directly from Table I (no *)
PAPER_RESULTS = {
    "U-Net†":       {"dice": 67.40, "iou": 54.90, "acc": None,  "rec": 70.80, "pre": None},
    "DoubleU-Net†": {"dice": 89.62, "iou": 82.12, "acc": None,  "rec": 87.80, "pre": 94.59},
    "Swin-UNet†":   {"dice": 89.72, "iou": 82.90, "acc": None,  "rec": 90.32, "pre": 92.04},
    "SegFormer†":   {"dice": 90.24, "iou": 83.60, "acc": None,  "rec": 91.12, "pre": 92.10},
    "MCTrans†":     {"dice": 90.35, "iou": None,  "acc": None,  "rec": None,  "pre": None},
}

MODEL_LABELS = {
    "unet":             "U-Net*",
    "doubleunet":       "DoubleU-Net*",
    "transattunet":     "TransAttUNet_R*",
    "htan_1_n2":        "HTAN_1 n=2 (Ours)",
    "htan_1_n4":        "HTAN_1 n=4 (Ours)",
    "htan_2_n2":        "HTAN_2 n=2 (Ours)",
    "htan_2_n4":        "HTAN_2 n=4 (Ours)",
    "htan_1_hres_only": "HTAN_1 Hres-only (Ours)",
}

OUR_RESULTS = {}
for key, label in MODEL_LABELS.items():
    path = RESULTS_DIR / f"{key}.json"
    if path.exists():
        with open(path) as f:
            data = json.load(f)
        OUR_RESULTS[label] = {k: data[k] for k in ["dice", "iou", "acc", "rec", "pre"]}
    else:
        print(f"Not trained yet: {key}")

def fmt(v):
    return f"{v:.2f}" if v is not None else "—"

ALL = {**PAPER_RESULTS, **OUR_RESULTS}
print(f"\n{'Method':<26} {'Dice':>6} {'IoU':>6} {'ACC':>6} {'REC':>6} {'PRE':>6}")
print("-" * 58)
for name, m in ALL.items():
    print(f"{name:<26} {fmt(m['dice']):>6} {fmt(m['iou']):>6} "
          f"{fmt(m['acc']):>6} {fmt(m['rec']):>6} {fmt(m['pre']):>6}")

# %% [markdown]
# ## 1.6 Training Curves

# %%
def load_history(model_name):
    path = SAVES_ROOT / model_name / "resume_checkpoint.pth"
    if not path.exists():
        print(f"No checkpoint: {model_name}")
        return None
    return torch.load(path, map_location="cpu")["history"]

def plot_metric(histories, metric, title):
    plt.figure(figsize=(10, 5))
    for name, h in histories.items():
        if h and metric in h:
            plt.plot(h[metric], label=name)
    plt.xlabel("Epoch")
    plt.ylabel(metric.capitalize())
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

MODELS = list(MODEL_LABELS.keys())
histories = {m: load_history(m) for m in MODELS}

plot_metric(histories, "dice",       "1.6.1 Validation Dice")
plot_metric(histories, "iou",        "1.6.2 Validation IoU")
plot_metric(histories, "train_loss", "1.6.3 Training Loss")
plot_metric(histories, "val_loss",   "1.6.4 Validation Loss")

# %% [markdown]
# ## 1.7 Ablation Table

# %%
ABLATION = [
    ("transattunet",     "—", "—",    "none",  "TransAttUNet_R (baseline)"),
    ("htan_1_hres_only", "1", "4",    "H_res", "HTAN_1 Hres-only"),
    ("htan_1_n2",        "1", "2",    "full",  "HTAN_1 n=2"),
    ("htan_1_n4",        "1", "4",    "full",  "HTAN_1 n=4"),
    ("htan_2_n2",        "2", "2",    "full",  "HTAN_2 n=2"),
    ("htan_2_n4",        "2", "4",    "full",  "HTAN_2 n=4"),
]

print(f"{'Model':<26} {'Blocks':>6} {'n':>4} {'Mappings':>10} {'Dice':>6} {'IoU':>6}")
print("-" * 62)

for key, blocks, n_val, mappings, name in ABLATION:
    path = RESULTS_DIR / f"{key}.json"
    if path.exists():
        with open(path) as f:
            d = json.load(f)
        dice, iou = f"{d['dice']:.2f}", f"{d['iou']:.2f}"
    else:
        dice = iou = "—"
    print(f"{name:<26} {blocks:>6} {n_val:>4} {mappings:>10} {dice:>6} {iou:>6}")

# %% [markdown]
# ## 1.8 Visual Predictions

# %%
from datasets.isic_dataset import get_loaders

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

def load_best(model, model_name):
    path = SAVES_ROOT / model_name / "best_model.pth"
    if not path.exists():
        print(f"No best model: {model_name}")
        return None
    model.load_state_dict(torch.load(path, map_location=DEVICE))
    return model.to(DEVICE).eval()

_, val_loader = get_loaders(batch_size=4)
imgs, masks   = next(iter(val_loader))
imgs_gpu      = imgs.to(DEVICE)

tan  = load_best(UNet_Attention_Transformer_Multiscale(3, 1), "transattunet")
htan = load_best(HTAN_1(expansion_n=4), "htan_1_n4")

with torch.no_grad():
    pred_tan  = (torch.sigmoid(tan(imgs_gpu))  > 0.5).cpu() if tan  else None
    pred_htan = (torch.sigmoid(htan(imgs_gpu)) > 0.5).cpu() if htan else None

def denorm(t):
    return (t * 0.5 + 0.5).clamp(0, 1)

n_show = min(4, imgs.shape[0])
fig, axes = plt.subplots(n_show, 4, figsize=(16, 4 * n_show))
fig.suptitle("1.8 Visual Predictions — ISIC-2018", fontsize=14, fontweight="bold")

for col, title in enumerate(["Input", "Ground Truth", "TransAttUNet", "HTAN_1 n=4"]):
    axes[0, col].set_title(title, fontweight="bold")

for i in range(n_show):
    axes[i, 0].imshow(denorm(imgs[i]).permute(1, 2, 0).numpy())
    axes[i, 1].imshow(masks[i, 0].numpy(), cmap="gray")
    axes[i, 2].imshow(pred_tan[i, 0].numpy()  if pred_tan  is not None else np.zeros((256, 256)), cmap="gray")
    axes[i, 3].imshow(pred_htan[i, 0].numpy() if pred_htan is not None else np.zeros((256, 256)), cmap="gray")
    for ax in axes[i]: ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # 2. Lung Field Segmentation
# *Coming soon — JSRT + Montgomery + NIH datasets*

# %% [markdown]
# ---
# # 3. COVID-19 Pneumonia Segmentation
# *Coming soon — Clean-CC-CCII dataset*

# %% [markdown]
# ---
# # 4. Nuclei Segmentation
# *Coming soon — 2018 Data Science Bowl dataset*

# %% [markdown]
# ---
# # 5. Gland Segmentation
# *Coming soon — GlaS dataset*
